# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosYepez/Construcci-n-calentamiento-/blob/main/Problema_archivo_breast_cancer_wisconsin_data_csv_Marcos_Y%C3%A9pez_1090192.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
files.upload()
# Out:
#      <input type="file" id="files-b2b417f3-27eb-4a31-a99c-4f8c32e799d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2b417f3-27eb-4a31-a99c-4f8c32e799d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
breast_train = pd.read_csv('/content/breast-cancer-wisconsin-data_set.csv')

# %%
breast_train.info()
# Out:
#           Id  ClumpThickness  UnifCellSize  UnifCellShape  MargAdhesion  \
# 0    1002945               5             4              4             5
# 1    1015425               3             1              1             1
# 2    1016277               6             8              8             1
# 3    1017023               4             1              1             3
# 4    1017122               8            10             10             8
# ..       ...             ...           ...            ...           ...
# 689   776715               3             1              1             1
# 690   841769               2             1              1             1
# 691   888820               5            10             10             3
# 692   897471               4             8              6             4
# 693   897471               4             8              8             5
#
#      EpitCellSize  BareNuclei   BlandChromatin  NormalNucleoli  Mitoses  Class
# ...

# %%
import numpy as np
dataForBreast = dataForBreast[dataForBreast['BareNuclei '] != '?']
dataForBreast.loc[dataForBreast['BareNuclei '] == '?']
dataForBreast['BareNuclei '] = dataForBreast['BareNuclei '].astype(np.int64)
# Out:
# <ipython-input-14-d08a00b1c5be>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataForBreast['BareNuclei '] = dataForBreast['BareNuclei '].astype(np.int64)

# %%
dataForBreast.corr()
# Out:
#                       Id  ClumpThickness  UnifCellSize  UnifCellShape  \
# Id              1.000000       -0.057402     -0.041852      -0.042971
# ClumpThickness -0.057402        1.000000      0.642859       0.652608
# UnifCellSize   -0.041852        0.642859      1.000000       0.907159
# UnifCellShape  -0.042971        0.652608      0.907159       1.000000
# MargAdhesion   -0.070033        0.488895      0.706455       0.685571
# EpitCellSize   -0.048958        0.522323      0.753074       0.722206
# BareNuclei     -0.100443        0.590070      0.691055       0.712239
# BlandChromatin -0.062925        0.549402      0.756199       0.734755
# NormalNucleoli -0.051877        0.527840      0.720408       0.717692
# Mitoses        -0.037986        0.354783      0.461245       0.442442
# Class          -0.085667        0.712921      0.820662       0.821157
#
#                 MargAdhesion  EpitCellSize  BareNuclei   BlandChromatin  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
data_to_drop = ['Class', 'UnifCellSize', 'UnifCellShape', 'BareNuclei ']
X_train, X_test, y_train, y_test = train_test_split(dataForBreast.drop(data_to_drop, axis=1), dataForBreast['Class'], test_size=0.30)

# %%
scaler = StandardScaler()
X_train_normalized = scaler.fit_transform(X_train)
model = LogisticRegression().fit(X_train_normalized, y_train)

# %%
model.score(X_train_normalized, y_train)
# Out:
# 0.9620253164556962

# %%
from sklearn.metrics import confusion_matrix
y_predicted = model.predict(X_test).reshape(-1, 1)
confusion_matrix(y_test, y_predicted)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([[130,   0],
#        [ 74,   0]])

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model, X_test, y_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predicted)
# Out:
# 0.6372549019607843

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()

X_train = lda.fit(X_train_normalized, y_train)

# %%
explained_variance = lda.explained_variance_ratio_
explained_variance
# Out:
# array([1.])

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_predicted)
# Out:
# array([[130,   0],
#        [ 74,   0]])

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lda, X_test, y_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearDiscriminantAnalysis was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predicted)
# Out:
# 0.6372549019607843
